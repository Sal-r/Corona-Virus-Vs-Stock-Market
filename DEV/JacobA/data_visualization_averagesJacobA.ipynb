# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
full_df = pd.read_csv("../../MVP/Data/full_df.csv")
full_df.head()
# Out:
#         dates stock    open   close    high       low    volume       category
# 0  2020-03-26  NFLX  344.00  362.99  363.84  341.7300   7191152  Entertainment
# 1  2020-03-25  NFLX  361.02  342.39  362.00  339.1700   8767171  Entertainment
# 2  2020-03-24  NFLX  369.99  357.32  372.93  353.0301  11638683  Entertainment
# 3  2020-03-23  NFLX  347.89  360.27  366.11  340.8838  13449378  Entertainment
# 4  2020-03-20  NFLX  342.31  332.83  350.49  332.0000  10853846  Entertainment

# %%
ent_df = full_df[full_df['category'] == 'Entertainment']
food_df = full_df[full_df['category'] == 'Food']
ess_df = full_df[full_df['category'] == 'Essentials']
cars_df = full_df[full_df['category'] == 'Cars']
tech_df = full_df[full_df['category'] == 'Tech']
global_df = full_df[full_df['category'] == 'Global']
comm_df = full_df[full_df['category'] == 'Commodities']
index_df = full_df[full_df['category'] == 'Index']

xticks = ["2019-02-01", "2019-03-01", "2019-04-01", "2019-05-01", "2019-06-03", "2019-07-01", "2019-08-01", "2019-09-03", "2019-10-01", "2019-11-01", "2019-12-02", "2020-01-02", "2020-02-03", "2020-03-02", "2020-03-26"]
places = [0, 18, 37, 58, 79, 99, 122, 142, 164, 186, 206, 228, 249, 270, 289]

# %%
def plot_avg_data(df, title):
    df = df.sort_values('dates', ascending=True)
    groupdf = df.groupby('dates').mean()

    ax = plt.subplot(111)
    groupdf.plot(y='close', kind='line', ax=ax, figsize=(20,5), legend=False)
    plt.xticks(places, xticks)
    plt.ylim(0)
    plt.xlabel('Date')
    plt.ylabel('Average Close Price')
    plt.title(title)
    return ax

# %%
ent_av_chart = plot_avg_data(ent_df, 'Entertainment Industry Average')

# %%
food_avg_chart = plot_avg_data(food_df, 'Food Industry Average ')

# %%
ess_avg_chart = plot_avg_data(ess_df, 'Essentials Industry Average')

# %%
cars_avg_chart = plot_avg_data(cars_df, 'Cars Industry Average')

# %%
tech_avg_chart = plot_avg_data(tech_df, 'Tech Industry Average')

# %%
global_avg_chart = plot_avg_data(global_df, 'Global Industry Average')

# %%
comm_avg_chart = plot_avg_data(comm_df, 'Commodities Industry Average')
