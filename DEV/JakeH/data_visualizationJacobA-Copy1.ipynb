# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
full_df = pd.read_csv("../../MVP/Data/full_df.csv")
full_df.head()
# Out:
#         dates stock    open   close    high       low    volume       category
# 0  2020-03-26  NFLX  344.00  362.99  363.84  341.7300   7191152  Entertainment
# 1  2020-03-25  NFLX  361.02  342.39  362.00  339.1700   8767171  Entertainment
# 2  2020-03-24  NFLX  369.99  357.32  372.93  353.0301  11638683  Entertainment
# 3  2020-03-23  NFLX  347.89  360.27  366.11  340.8838  13449378  Entertainment
# 4  2020-03-20  NFLX  342.31  332.83  350.49  332.0000  10853846  Entertainment

# %%
full_2008_df = pd.read_csv("../../MVP/Data/full_2008_df.csv")
full_2008_df.head()
# Out:
#         dates stock   open  close   high    low    volume category
# 0  2009-03-26    KO  44.95  44.85  45.00  43.82  13903900     Food
# 1  2009-03-25    KO  44.40  44.75  44.89  44.03  12242700     Food
# 2  2009-03-24    KO  43.60  44.02  44.34  43.41  10939400     Food
# 3  2009-03-23    KO  43.16  44.14  44.14  43.00  13250700     Food
# 4  2009-03-20    KO  42.32  42.64  43.14  42.31  19164400     Food

# %%
ent_df = full_df[full_df['category'] == 'Entertainment']
food_df = full_df[full_df['category'] == 'Food']
ess_df = full_df[full_df['category'] == 'Essentials']
cars_df = full_df[full_df['category'] == 'Cars']
tech_df = full_df[full_df['category'] == 'Tech']
global_df = full_df[full_df['category'] == 'Global']
comm_df = full_df[full_df['category'] == 'Commodities']
index_df = full_df[full_df['category'] == 'Index']

# %%
#ent_08_df = full_2008_df[full_2008_df['category'] == 'Entertainment']
food_08_df = full_2008_df[full_2008_df['category'] == 'Food'] #08
#ess_08_df = full_2008_df[full_2008_df['category'] == 'Essentials']
cars_08_df = full_2008_df[full_2008_df['category'] == 'Cars'] #08
#tech_08_df = full_2008_df[full_2008_df['category'] == 'Tech']
#global_08_df = full_2008_df[full_2008_df['category'] == 'Global']
comm_08_df = full_2008_df[full_2008_df['category'] == 'Commodities'] #08
index_08_df = full_2008_df[full_2008_df['category'] == 'Index'] #08

# %%
def plot_data(df_20, df_08, title, title_08):
    df_20 = df_20.sort_values('dates', ascending=True)
    groupdf_20 = df_20.groupby('stock')
    
    stock_20 = groupdf_20.stock.unique()
    stock_list_20 = stock_20.index
    
    df_08 = df_08.sort_values('dates', ascending=True)
    groupdf_08 = df_08.groupby('stock')
    
    stock_08 = groupdf_08.stock.unique()
    stock_list_08 = stock_08.index

    fig = plt.figure(figsize=(20,10))
    
    ax = fig.add_subplot(211)
    groupdf_20.plot(y='close', x='dates', kind='line', ax=ax)
    plt.legend(stock_list_20, loc='best')
    plt.xlabel('Date')
    plt.ylabel('Close Price')
    plt.title(title)
    
    ax = fig.add_subplot(212)
    groupdf_08.plot(y='close', x='dates', kind='line', ax=ax)
    plt.legend(stock_list_08, loc='best')
    plt.xlabel('Date')
    plt.ylabel('Close Price')
    plt.title(title_08)
    
    plt.show()
    
    
    return ax

# %%
food_chart = plot_data(food_df, food_08_df, '2020 Food Stock Prices', '2008 Food Stock Prices')

# %%
cars_chart = plot_data(cars_df, cars_08_df, '2020 Cars Stock Prices', '2008 Cars Stock Prices')

# %%
comm_chart = plot_data(comm_df, comm_08_df, '2020 Commodities Stock Prices', '2008 Commodities Stock Prices')

# %%
index_chart = plot_data(index_df, index_08_df, '2020 Index Stock Prices', '2008 Index Stock Prices')
