# %%
import pandas as pd

# %%
pip install alpha_vantage pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='A0DF51WHUDBQ8UOH')
# Get json object with the get_daily data and another with  the call's metadata
data, meta_data = ts.get_daily('GOOGL')
data_frame = pd.DataFrame(data)
# Out:
# {'2020-03-20': {'1. open': '1130.9000',
#   '2. high': '1138.4800',
#   '3. low': '1062.1000',
#   '4. close': '1068.2100',
#   '5. volume': '4088847'},
#  '2020-03-19': {'1. open': '1088.2200',
#   '2. high': '1152.6100',
#   '3. low': '1055.5500',
#   '4. close': '1111.6700',
#   '5. volume': '3703248'},
#  '2020-03-18': {'1. open': '1059.9400',
#   '2. high': '1104.9900',
#   '3. low': '1037.0000',
#   '4. close': '1091.1900',
#   '5. volume': '4636840'},
#  '2020-03-17': {'1. open': '1090.6400',
#   '2. high': '1126.0000',
#   '3. low': '1049.1000',
#   '4. close': '1118.0600',
#   '5. volume': '4159686'},
#  '2020-03-16': {'1. open': '1089.6100',
#   '2. high': '1145.4700',
#   '3. low': '1067.0800',
#   '4. close': '1073.0000',
#   '5. volume': '4825981'},
#  '2020-03-13': {'1. open': '1174.9900',
#   '2. high': '1214.4000',
#   '3. low': '1112.2900',
#   '4. close': '1214.2700',
#   '5. volume': '3969973'},
#  '2020-03-12': {'1. open': '1122.6200',
#   '2. high': '1188.7500',
# ...

# %%
data_frame = pd.DataFrame(data)
data_frame
# Out:
#           2020-03-20 2020-03-19 2020-03-18 2020-03-17 2020-03-16 2020-03-13  \
# 1. open    1130.9000  1088.2200  1059.9400  1090.6400  1089.6100  1174.9900
# 2. high    1138.4800  1152.6100  1104.9900  1126.0000  1145.4700  1214.4000
# 3. low     1062.1000  1055.5500  1037.0000  1049.1000  1067.0800  1112.2900
# 4. close   1068.2100  1111.6700  1091.1900  1118.0600  1073.0000  1214.2700
# 5. volume    4088847    3703248    4636840    4159686    4825981    3969973
#
#           2020-03-12 2020-03-11 2020-03-10 2020-03-09  ... 2019-11-08  \
# 1. open    1122.6200  1248.2700  1254.3900  1204.9600  ...  1301.5200
# 2. high    1188.7500  1256.9300  1275.8500  1252.7300  ...  1317.1100
# 3. low     1108.4700  1191.1400  1214.5100  1198.0400  ...  1301.5200
# 4. close   1111.5500  1210.9000  1275.1700  1215.7900  ...  1309.0000
# 5. volume    4716293    2741694    2743566    3462578  ...    1521892
#
#           2019-11-07 2019-11-06 2019-11-05 2019-11-04 2019-11-01 2019-10-31  \
# ...
